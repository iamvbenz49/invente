# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/ml-alchemy/Sample_Submission.csv
# /kaggle/input/ml-alchemy/Train.csv
# /kaggle/input/ml-alchemy/Test.csv

# %%
dataset = pd.read_csv("/kaggle/input/ml-alchemy/Sample_Submission.csv")
dataset.head()
# Out:
#    UniqueID  will_go_to_college
# 0         1               False
# 1        85               False
# 2        68               False
# 3         2               False
# 4         9               False

# %%
train = pd.read_csv("/kaggle/input/ml-alchemy/Train.csv")
train.head()
# Out:
#    UniqueID type_school school_accreditation  gender         interest  \
# 0        30  Vocational                    B  Female        Uncertain
# 1       536  Vocational                    A    Male  Very Interested
# 2       696  Vocational                    A  Female  Very Interested
# 3       558    Academic                    A    Male   Not Interested
# 4       837  Vocational                    B    Male        Uncertain
#
#   residence  parent_age  parent_salary  house_area  average_grades  \
# 0     Rural        50.0      6450000.0        78.4           85.86
# 1     Urban        54.0      5450000.0        70.3             NaN
# 2     Urban        52.0      5520000.0        82.5           84.59
# 3     Rural        41.0      3020000.0        50.6           77.18
# 4     Rural        52.0      6120000.0        65.8           84.55
#
#   parent_was_in_college  will_go_to_college
# 0                  True               False
# 1                 False                True
# ...

# %%
test = pd.read_csv("/kaggle/input/ml-alchemy/Test.csv")
test.head()
# Out:
#    UniqueID type_school school_accreditation  gender         interest  \
# 0       522  Vocational                    A    Male  Less Interested
# 1       738  Vocational                    A  Female  Very Interested
# 2       741    Academic                    B    Male   Not Interested
# 3       661    Academic                    A  Female  Less Interested
# 4       412  Vocational                    B    Male  Very Interested
#
#   residence  parent_age  parent_salary  house_area  average_grades  \
# 0     Urban        59.0      5390000.0        63.3           86.49
# 1     Urban        53.0      6150000.0        54.4           85.46
# 2     Rural        48.0      3320000.0        72.8           83.63
# 3     Urban        60.0      3670000.0        83.5           88.30
# 4     Urban        56.0      6040000.0        75.6           87.46
#
#   parent_was_in_college
# 0                 False
# 1                 False
# 2                  True
# 3                 False
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = train.iloc[:, :-1] 
y_train = train['will_go_to_college']
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32/540437227.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
#       3 X_train = train.iloc[:, :-1]
#       4 y_train = train['will_go_to_college']
# ----> 5 X_train = sc.fit_transform(X_train)
#       6 X_test = sc.transform(X_test)
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return (
#
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py in ?(self, X, y, **fit_params)
# ...

# %%
test

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# Initialize models
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Support Vector Classifier': SVC(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Naive Bayes': GaussianNB()
}

# Train and evaluate models
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(test)
    
    accuracy = accuracy_score(test, y_pred)
    print(f"Model: {model_name}")
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, y_pred))
    print("="*30)
